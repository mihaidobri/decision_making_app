# %% [markdown]
# <a href="https://colab.research.google.com/github/mihaidobri/decision_making_app/blob/master/data_prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# # Downloads

# %% [markdown]
# # Imports

# %% [markdown]
# # Data

# %%
file = open('test_file','w')
file.write('Hello word')
file.close()

# %%
with open('test_file',mode='r') as f:
  data=f.readlines()
  print(data)
# Out:
# ['Hello word']
